# %% [markdown]
# <a href="https://github.com/nghiencuuthuoc/PharmApp/PharmApp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# ![](https://raw.githubusercontent.com/nghiencuuthuoc/PharmApp/master/PharmApp-logo.png)
# # PharmApp - Drug Discovery and Development
# Copyright 2021 | Nghiên Cứu Thuốc | RD Pharma Plus
#
# Email: nghiencuuthuoc@gmail.com | info@nghiencuuthuoc.com
#
# Web: http://www.nghiencuuthuoc.com
#
# See more: https://twitter.com/nghiencuuthuoc | https://facebook.com/nghiencuuthuoc

# %% [markdown]
# # PharmApp - Brand Name Drugs

# %% [markdown]
# > [**Reference:**](https://github.com/nghiencuuthuoc/PharmApp)

# %% [markdown]
# ## drugbank_top_products

# %%
try:
    # drug name
    drugs_raw = "Cabenuva"
    drugs = drugs_raw.split(" ")
    # get inactive ingredient
    import pharmapp as pa
    for drug in drugs:
        print(drug)
        pa.get_inactive_ingredient(name_drug=drug)
        print(f'{drug} done!')
        print("+---------------------------+---------------------------+")
        continue
except:
    
#     continue
    pass
# finally:
#     continue
# Out:
# Cabenuva
# Start import package
# Import package done!
# Output file done!
# Link file done!
# Output1 file done!
# Not find cabenuva on DailyMed

# %%
import pandas as pd
pd.set_option("display.max_rows", None, "display.max_columns", None)

df_iig = pd.read_csv('nexium_inactive_ingredient_list.txt')
df_iig
# Out:
#                    MainDrug         NDC        Strength  \
# 0    esomeprazole magnesium   0573-2450           20 mg
# 1    esomeprazole magnesium   0573-2450           20 mg
# 2    esomeprazole magnesium   0573-2450           20 mg
# 3    esomeprazole magnesium   0573-2450           20 mg
# 4    esomeprazole magnesium   0573-2450           20 mg
# 5    esomeprazole magnesium   0573-2450           20 mg
# 6    esomeprazole magnesium   0573-2450           20 mg
# 7    esomeprazole magnesium   0573-2450           20 mg
# 8    esomeprazole magnesium   0573-2450           20 mg
# 9    esomeprazole magnesium   0573-2450           20 mg
# 10   esomeprazole magnesium   0573-2450           20 mg
# 11   esomeprazole magnesium   0573-2450           20 mg
# 12   esomeprazole magnesium   0573-2450           20 mg
# 13   esomeprazole magnesium   0573-2450           20 mg
# 14   esomeprazole magnesium   0573-2450           20 mg
# 15   esomeprazole magnesium   0573-2450           20 mg
# 16   esomeprazole magnesium   0573-2452           20 mg
# 17   esomeprazole magnesium   0573-2452           20 mg
# 18   esomeprazole magnesium   0573-2452           20 mg
# 19   esomeprazole magnesium   0573-2452           20 mg
# 20   esomeprazole magnesium   0573-2452           20 mg
# 21   esomeprazole magnesium   0573-2452           20 mg
# 22   esomeprazole magnesium   0573-2452           20 mg
# 23   esomeprazole magnesium   0573-2452           20 mg
# 24   esomeprazole magnesium   0573-2452           20 mg
# 25   esomeprazole magnesium   0573-2452           20 mg
# 26   esomeprazole magnesium   0573-2452           20 mg
# 27   esomeprazole magnesium   0573-2452           20 mg
# 28   esomeprazole magnesium   0573-2452           20 mg
# 29   esomeprazole magnesium   0573-2452           20 mg
# 30   esomeprazole magnesium   0573-2452           20 mg
# 31   esomeprazole magnesium   0573-2452           20 mg
# 32   esomeprazole magnesium   0573-2452           20 mg
# 33   esomeprazole magnesium   0573-2451           20 mg
# 303               0186-5020   16590-625           20 mg
# 304               0186-5020   16590-625           20 mg
# 305               0186-5020   16590-625           20 mg
# 306               0186-5020   16590-625           20 mg
# 307               0186-5020   16590-625           20 mg
# 308               0186-5020   16590-625           20 mg
# 309               0186-5020   16590-625           20 mg
# 310               0186-5020   16590-625           20 mg
# 311               0186-5020   16590-625           20 mg
# 312               0186-5020   16590-625           20 mg
#
#                                            Formulation  \
# 0                             capsule, delayed release
# 1                             capsule, delayed release
# 2                             capsule, delayed release
# 3                             capsule, delayed release
# 4                             capsule, delayed release
# 5                             capsule, delayed release
# 6                             capsule, delayed release
# 7                             capsule, delayed release
# 8                             capsule, delayed release
# 9                             capsule, delayed release
# 10                            capsule, delayed release
# 11                            capsule, delayed release
# 12                            capsule, delayed release
# 13                            capsule, delayed release
# 14                            capsule, delayed release
# 15                            capsule, delayed release
# 16                            capsule, delayed release
# 17                            capsule, delayed release
# 18                            capsule, delayed release
# 19                            capsule, delayed release
# 20                            capsule, delayed release
# 21                            capsule, delayed release
# 22                            capsule, delayed release
# 23                            capsule, delayed release
# 24                            capsule, delayed release
# 25                            capsule, delayed release
# 26                            capsule, delayed release
# 27                            capsule, delayed release
# 28                            capsule, delayed release
# 29                            capsule, delayed release
# 30                            capsule, delayed release
# 31                            capsule, delayed release
# 32                            capsule, delayed release
# 33                                              tablet
# 34                                              tablet
# 35                                              tablet
# 36                                              tablet
# 37                                              tablet
# 38                                              tablet
# 39                                              tablet
# 40                                              tablet
# 41                                              tablet
# 42                                              tablet
# 43                                              tablet
# 44                                              tablet
# 45                                              tablet
# 46                                              tablet
# 47                                              tablet
# 48                                              tablet
# 49                                              tablet
# 50                                              tablet
# 51                                              tablet
# 52                                              tablet
# 53                            capsule, delayed release
# 54                            capsule, delayed release
# 55                            capsule, delayed release
# 56                            capsule, delayed release
# 57                            capsule, delayed release
# 58                            capsule, delayed release
# 59                            capsule, delayed release
# 60                            capsule, delayed release
# 61                            capsule, delayed release
# 62                            capsule, delayed release
# 63                            capsule, delayed release
# 64                            capsule, delayed release
# 65                            capsule, delayed release
# 66                            capsule, delayed release
# 67                            capsule, delayed release
# 68                            capsule, delayed release
# 69                            capsule, delayed release
# 70                            capsule, delayed release
# 71                            capsule, delayed release
# 72                            capsule, delayed release
# 73                            granule, delayed release
# 74                            granule, delayed release
# 75                            granule, delayed release
# 76                            granule, delayed release
# 77                            granule, delayed release
# 78                            granule, delayed release
# 79                            granule, delayed release
# 80                            granule, delayed release
# 81                            granule, delayed release
# 82                            granule, delayed release
# 83                            granule, delayed release
# 84                            granule, delayed release
# 85                            granule, delayed release
# 86                            granule, delayed release
# 87                            granule, delayed release
# 88                            granule, delayed release
# 89                            granule, delayed release
# 90                            granule, delayed release
# 91                            granule, delayed release
# 92                            granule, delayed release
# 93                            granule, delayed release
# 94                            granule, delayed release
# 95                            granule, delayed release
# 96                            granule, delayed release
# 97                            granule, delayed release
# 98                            granule, delayed release
# 99                            granule, delayed release
# 100                           granule, delayed release
# 101                           granule, delayed release
# 102                           granule, delayed release
# 103                           granule, delayed release
# 104                           granule, delayed release
# 105                           granule, delayed release
# 106                           granule, delayed release
# 107                           granule, delayed release
# 108                           granule, delayed release
# 109                           granule, delayed release
# 110                           granule, delayed release
# 111                           granule, delayed release
# 112                           granule, delayed release
# 113                           granule, delayed release
# 114                           granule, delayed release
# 115                           capsule, delayed release
# 116                           capsule, delayed release
# 117                           capsule, delayed release
# 118                           capsule, delayed release
# 119                           capsule, delayed release
# 120                           capsule, delayed release
# 121                           capsule, delayed release
# 122                           capsule, delayed release
# 123                           capsule, delayed release
# 124                           capsule, delayed release
# 125                           capsule, delayed release
# 126                           capsule, delayed release
# 127                           capsule, delayed release
# 128                           capsule, delayed release
# 129                           capsule, delayed release
# 130                           capsule, delayed release
# 131                           capsule, delayed release
# 132                           capsule, delayed release
# 133                           capsule, delayed release
# 134                           capsule, delayed release
# 135                                          injection
# 136                                          injection
# 137    esomeprazole magnesium capsule, delayed release
# 138    esomeprazole magnesium capsule, delayed release
# 139    esomeprazole magnesium capsule, delayed release
# 140    esomeprazole magnesium capsule, delayed release
# 141    esomeprazole magnesium capsule, delayed release
# 142    esomeprazole magnesium capsule, delayed release
# 143    esomeprazole magnesium capsule, delayed release
# 144    esomeprazole magnesium capsule, delayed release
# 145    esomeprazole magnesium capsule, delayed release
# 146    esomeprazole magnesium capsule, delayed release
# 147    esomeprazole magnesium capsule, delayed release
# 148    esomeprazole magnesium capsule, delayed release
# 149    esomeprazole magnesium capsule, delayed release
# 150    esomeprazole magnesium capsule, delayed release
# 151    esomeprazole magnesium capsule, delayed release
# 152    esomeprazole magnesium capsule, delayed release
# 153    esomeprazole magnesium capsule, delayed release
# 154    esomeprazole magnesium capsule, delayed release
# 155    esomeprazole magnesium capsule, delayed release
# 156    esomeprazole magnesium capsule, delayed release
# 157    esomeprazole magnesium capsule, delayed release
# 158    esomeprazole magnesium capsule, delayed release
# 159    esomeprazole magnesium capsule, delayed release
# 160    esomeprazole magnesium capsule, delayed release
# 161    esomeprazole magnesium capsule, delayed release
# 162    esomeprazole magnesium capsule, delayed release
# 163    esomeprazole magnesium capsule, delayed release
# 164    esomeprazole magnesium capsule, delayed release
# 165    esomeprazole magnesium capsule, delayed release
# 166    esomeprazole magnesium capsule, delayed release
# 167    esomeprazole magnesium capsule, delayed release
# 168    esomeprazole magnesium capsule, delayed release
# 169    esomeprazole magnesium capsule, delayed release
# 170    esomeprazole magnesium capsule, delayed release
# 171  esomeprazole magnesium 20mg capsule, delayed r...
# 172    esomeprazole magnesium capsule, delayed release
# 173    esomeprazole magnesium capsule, delayed release
# 174    esomeprazole magnesium capsule, delayed release
# 175    esomeprazole magnesium capsule, delayed release
# 176    esomeprazole magnesium capsule, delayed release
# 177    esomeprazole magnesium capsule, delayed release
# 178    esomeprazole magnesium capsule, delayed release
# 179    esomeprazole magnesium capsule, delayed release
# 180    esomeprazole magnesium capsule, delayed release
# 181    esomeprazole magnesium capsule, delayed release
# 182    esomeprazole magnesium capsule, delayed release
# 183    esomeprazole magnesium capsule, delayed release
# 184    esomeprazole magnesium capsule, delayed release
# 185    esomeprazole magnesium capsule, delayed release
# 186    esomeprazole magnesium capsule, delayed release
# 187    esomeprazole magnesium capsule, delayed release
# 188    esomeprazole magnesium capsule, delayed release
# 189    esomeprazole magnesium capsule, delayed release
# 190    esomeprazole magnesium capsule, delayed release
# 191    esomeprazole magnesium capsule, delayed release
# 192    esomeprazole magnesium capsule, delayed release
# 193    esomeprazole magnesium capsule, delayed release
# 194    esomeprazole magnesium capsule, delayed release
# 195    esomeprazole magnesium capsule, delayed release
# 196    esomeprazole magnesium capsule, delayed release
# 197    esomeprazole magnesium capsule, delayed release
# 198    esomeprazole magnesium capsule, delayed release
# 199    esomeprazole magnesium capsule, delayed release
# 200    esomeprazole magnesium capsule, delayed release
# 201    esomeprazole magnesium capsule, delayed release
# 202    esomeprazole magnesium capsule, delayed release
# 203    esomeprazole magnesium capsule, delayed release
# 204    esomeprazole magnesium capsule, delayed release
# 205    esomeprazole magnesium capsule, delayed release
# 206    esomeprazole magnesium capsule, delayed release
# 207    esomeprazole magnesium capsule, delayed release
# 208    esomeprazole magnesium capsule, delayed release
# 209    esomeprazole magnesium capsule, delayed release
# 210    esomeprazole magnesium capsule, delayed release
# 211    esomeprazole magnesium capsule, delayed release
# 212    esomeprazole magnesium capsule, delayed release
# 213    esomeprazole magnesium capsule, delayed release
# 214    esomeprazole magnesium capsule, delayed release
# 215    esomeprazole magnesium capsule, delayed release
# 216    esomeprazole magnesium capsule, delayed release
# 217    esomeprazole magnesium capsule, delayed release
# 218    esomeprazole magnesium capsule, delayed release
# 219    esomeprazole magnesium capsule, delayed release
# 220    esomeprazole magnesium capsule, delayed release
# 221    esomeprazole magnesium capsule, delayed release
# 222    esomeprazole magnesium capsule, delayed release
# 223    esomeprazole magnesium capsule, delayed release
# 224    esomeprazole magnesium capsule, delayed release
# 225    esomeprazole magnesium capsule, delayed release
# 226    esomeprazole magnesium capsule, delayed release
# 227    esomeprazole magnesium capsule, delayed release
# 228    esomeprazole magnesium capsule, delayed release
# 229    esomeprazole magnesium capsule, delayed release
# 230    esomeprazole magnesium capsule, delayed release
# 231    esomeprazole magnesium capsule, delayed release
# 232    esomeprazole magnesium capsule, delayed release
# 233    esomeprazole magnesium capsule, delayed release
# 234    esomeprazole magnesium capsule, delayed release
# 235    esomeprazole magnesium capsule, delayed release
# 236    esomeprazole magnesium capsule, delayed release
# 237    esomeprazole magnesium capsule, delayed release
# 238    esomeprazole magnesium capsule, delayed release
# 239    esomeprazole magnesium capsule, delayed release
# 240    esomeprazole magnesium capsule, delayed release
# 241    esomeprazole magnesium capsule, delayed release
# 242    esomeprazole magnesium capsule, delayed release
# 243    esomeprazole magnesium capsule, delayed release
# 244    esomeprazole magnesium capsule, delayed release
# 245    esomeprazole magnesium capsule, delayed release
# 246    esomeprazole magnesium capsule, delayed release
# 247    esomeprazole magnesium capsule, delayed release
# 248    esomeprazole magnesium capsule, delayed release
# 249    esomeprazole magnesium capsule, delayed release
# 250    esomeprazole magnesium capsule, delayed release
# 251    esomeprazole magnesium capsule, delayed release
# 252    esomeprazole magnesium capsule, delayed release
# 253    esomeprazole magnesium capsule, delayed release
# 254    esomeprazole magnesium capsule, delayed release
# 255    esomeprazole magnesium capsule, delayed release
# 256    esomeprazole magnesium capsule, delayed release
# 257    esomeprazole magnesium capsule, delayed release
# 258    esomeprazole magnesium capsule, delayed release
# 259    esomeprazole magnesium capsule, delayed release
# 260    esomeprazole magnesium capsule, delayed release
# 261    esomeprazole magnesium capsule, delayed release
# 262    esomeprazole magnesium capsule, delayed release
# 263    esomeprazole magnesium capsule, delayed release
# 264    esomeprazole magnesium capsule, delayed release
# 265    esomeprazole magnesium capsule, delayed release
# 266    esomeprazole magnesium capsule, delayed release
# 267    esomeprazole magnesium capsule, delayed release
# 268    esomeprazole magnesium capsule, delayed release
# 269    esomeprazole magnesium capsule, delayed release
# 270    esomeprazole magnesium capsule, delayed release
# 271    esomeprazole magnesium capsule, delayed release
# 272    esomeprazole magnesium capsule, delayed release
# 273    esomeprazole magnesium capsule, delayed release
# 274    esomeprazole magnesium capsule, delayed release
# 275    esomeprazole magnesium capsule, delayed release
# 276    esomeprazole magnesium capsule, delayed release
# 277    esomeprazole magnesium capsule, delayed release
# 278    esomeprazole magnesium capsule, delayed release
# 279    esomeprazole magnesium capsule, delayed release
# 280    esomeprazole magnesium capsule, delayed release
# 281    esomeprazole magnesium capsule, delayed release
# 282    esomeprazole magnesium capsule, delayed release
# 283    esomeprazole magnesium capsule, delayed release
# 284    esomeprazole magnesium capsule, delayed release
# 285    esomeprazole magnesium capsule, delayed release
# 286    esomeprazole magnesium capsule, delayed release
# 287    esomeprazole magnesium capsule, delayed release
# 288    esomeprazole magnesium capsule, delayed release
# 289    esomeprazole magnesium capsule, delayed release
# 290    esomeprazole magnesium capsule, delayed release
# 291    esomeprazole magnesium capsule, delayed release
# 292   esomeprazole magnesium  capsule, delayed release
# 293   esomeprazole magnesium  capsule, delayed release
# 294   esomeprazole magnesium  capsule, delayed release
# 295   esomeprazole magnesium  capsule, delayed release
# 296   esomeprazole magnesium  capsule, delayed release
# 297   esomeprazole magnesium  capsule, delayed release
# 298   esomeprazole magnesium  capsule, delayed release
# 299   esomeprazole magnesium  capsule, delayed release
# 300   esomeprazole magnesium  capsule, delayed release
# 301   esomeprazole magnesium  capsule, delayed release
# 302   esomeprazole magnesium  capsule, delayed release
# 303   esomeprazole magnesium  capsule, delayed release
# 304   esomeprazole magnesium  capsule, delayed release
# 305   esomeprazole magnesium  capsule, delayed release
# 306   esomeprazole magnesium  capsule, delayed release
# 307   esomeprazole magnesium  capsule, delayed release
# 308   esomeprazole magnesium  capsule, delayed release
# 309   esomeprazole magnesium  capsule, delayed release
# 310   esomeprazole magnesium  capsule, delayed release
# 311   esomeprazole magnesium  capsule, delayed release
# 312   esomeprazole magnesium  capsule, delayed release
#
#                                               Inactive
# 0                                         STARCH, CORN
# 1                                   D&amp;C RED NO. 28
# 2                                  FD&amp;C BLUE NO. 1
# 3                                  FD&amp;C RED NO. 40
# 4                                     FERRIC OXIDE RED
# 5                                 GELATIN, UNSPECIFIED
# 6                                GLYCERYL MONOSTEARATE
# 7               HYDROXYPROPYL CELLULOSE (1600000 WAMW)
# 8                            HYPROMELLOSE, UNSPECIFIED
# 9                                   MAGNESIUM STEARATE
# 10   METHACRYLIC ACID - METHYL METHACRYLATE COPOLYM...
# 11                                      POLYSORBATE 80
# 12                                             SUCROSE
# 13                                                TALC
# 14                                    TITANIUM DIOXIDE
# 15                                    TRIETHYL CITRATE
# 16                                       CARMINIC ACID
# 17                                        STARCH, CORN
# 18                                 FD&amp;C BLUE NO. 2
# 19                                  FD&amp;C RED NO. 3
# 20                                 FD&amp;C RED NO. 40
# 21                                    FERRIC OXIDE RED
# 22                                GELATIN, UNSPECIFIED
# 23                               GLYCERYL MONOSTEARATE
# 24              HYDROXYPROPYL CELLULOSE (1600000 WAMW)
# 25                           HYPROMELLOSE, UNSPECIFIED
# 26                                  MAGNESIUM STEARATE
# 27   METHACRYLIC ACID - METHYL METHACRYLATE COPOLYM...
# 28                                      POLYSORBATE 80
# 29                                             SUCROSE
# 30                                                TALC
# 31                                    TITANIUM DIOXIDE
# 32                                    TRIETHYL CITRATE
# 33                                        STARCH, CORN
# 34                            CROSPOVIDONE (120 .MU.M)
# 35                                  D&amp;C RED NO. 27
# 36                                 FD&amp;C BLUE NO. 2
# 37                                 FD&amp;C RED NO. 40
# 38                               GLYCERYL MONOSTEARATE
# 39              HYDROXYPROPYL CELLULOSE (1600000 WAMW)
# 40                           HYPROMELLOSE, UNSPECIFIED
# 41                                  MAGNESIUM STEARATE
# 42   METHACRYLIC ACID - METHYL METHACRYLATE COPOLYM...
# 43                                                MICA
# 44                          MICROCRYSTALLINE CELLULOSE
# 45                                            PARAFFIN
# 46                    POLYETHYLENE GLYCOL, UNSPECIFIED
# 47                                      POLYSORBATE 80
# 48                             SODIUM STEARYL FUMARATE
# 49                                             SUCROSE
# 50                                                TALC
# 51                                    TITANIUM DIOXIDE
# 52                                    TRIETHYL CITRATE
# 53                               GLYCERYL MONOSTEARATE
# 54              HYDROXYPROPYL CELLULOSE (1600000 WAMW)
# 55                           HYPROMELLOSE, UNSPECIFIED
# 56                                  MAGNESIUM STEARATE
# 57                                    METHACRYLIC ACID
# 58                                                TALC
# 59                                    TRIETHYL CITRATE
# 60                                      POLYSORBATE 80
# 61                                GELATIN, UNSPECIFIED
# 62                                 FD&amp;C BLUE NO. 1
# 63                                 FD&amp;C RED NO. 40
# 64                                  D&amp;C RED NO. 28
# 65                                    TITANIUM DIOXIDE
# 66                                             ALCOHOL
# 67                                   ISOPROPYL ALCOHOL
# 68                                       BUTYL ALCOHOL
# 69                    POLYETHYLENE GLYCOL, UNSPECIFIED
# 70                                    SODIUM HYDROXIDE
# 71                               POVIDONE, UNSPECIFIED
# 72                               D&amp;C YELLOW NO. 10
# 73                               GLYCERYL MONOSTEARATE
# 74              HYDROXYPROPYL CELLULOSE (1600000 WAMW)
# 75                           HYPROMELLOSE, UNSPECIFIED
# 76                                  MAGNESIUM STEARATE
# 77                                    METHACRYLIC ACID
# 78                                   POTASSIUM SORBATE
# 79                                                TALC
# 80                                    TRIETHYL CITRATE
# 81                                               WATER
# 82                                  ANHYDROUS DEXTROSE
# 83                               POVIDONE, UNSPECIFIED
# 84                               ANHYDROUS CITRIC ACID
# 85                                 FERRIC OXIDE YELLOW
# 86                                             ALCOHOL
# 87                               GLYCERYL MONOSTEARATE
# 88              HYDROXYPROPYL CELLULOSE (1600000 WAMW)
# 89                           HYPROMELLOSE, UNSPECIFIED
# 90                                  MAGNESIUM STEARATE
# 91                                    METHACRYLIC ACID
# 92                                   POTASSIUM SORBATE
# 93                                                TALC
# 94                                    TRIETHYL CITRATE
# 95                                               WATER
# 96                                  ANHYDROUS DEXTROSE
# 97                               POVIDONE, UNSPECIFIED
# 98                               ANHYDROUS CITRIC ACID
# 99                                 FERRIC OXIDE YELLOW
# 100                                            ALCOHOL
# 101                              GLYCERYL MONOSTEARATE
# 102             HYDROXYPROPYL CELLULOSE (1600000 WAMW)
# 103                          HYPROMELLOSE, UNSPECIFIED
# 104                                 MAGNESIUM STEARATE
# 105                                   METHACRYLIC ACID
# 106                                  POTASSIUM SORBATE
# 107                                               TALC
# 108                                   TRIETHYL CITRATE
# 109                                              WATER
# 110                                 ANHYDROUS DEXTROSE
# 111                              POVIDONE, UNSPECIFIED
# 112                              ANHYDROUS CITRIC ACID
# 113                                FERRIC OXIDE YELLOW
# 114                                            ALCOHOL
# 115                              GLYCERYL MONOSTEARATE
# 116             HYDROXYPROPYL CELLULOSE (1600000 WAMW)
# 117                          HYPROMELLOSE, UNSPECIFIED
# 118                                 MAGNESIUM STEARATE
# 119                                   METHACRYLIC ACID
# 120                                               TALC
# 121                                   TRIETHYL CITRATE
# 122                                     POLYSORBATE 80
# 123                               GELATIN, UNSPECIFIED
# 124                                FD&amp;C BLUE NO. 1
# 125                                FD&amp;C RED NO. 40
# 126                                 D&amp;C RED NO. 28
# 127                                   TITANIUM DIOXIDE
# 128                                            ALCOHOL
# 129                                  ISOPROPYL ALCOHOL
# 130                                      BUTYL ALCOHOL
# 131                   POLYETHYLENE GLYCOL, UNSPECIFIED
# 132                                   SODIUM HYDROXIDE
# 133                              POVIDONE, UNSPECIFIED
# 134                              D&amp;C YELLOW NO. 10
# 135                                   EDETATE DISODIUM
# 136                                   SODIUM HYDROXIDE
# 137                             ESOMEPRAZOLE MAGNESIUM
# 138                                       STARCH, CORN
# 139                                 D&amp;C RED NO. 28
# 140                                FD&amp;C BLUE NO. 1
# 141                                FD&amp;C RED NO. 40
# 142                                   FERRIC OXIDE RED
# 143                               GELATIN, UNSPECIFIED
# 144                              GLYCERYL MONOSTEARATE
# 145             HYDROXYPROPYL CELLULOSE (1600000 WAMW)
# 146                          HYPROMELLOSE, UNSPECIFIED
# 147                                 MAGNESIUM STEARATE
# 148  METHACRYLIC ACID - METHYL METHACRYLATE COPOLYM...
# 149                                     POLYSORBATE 80
# 150                                            SUCROSE
# 151                                               TALC
# 152                                   TITANIUM DIOXIDE
# 153                                   TRIETHYL CITRATE
# 154                             ESOMEPRAZOLE MAGNESIUM
# 155                                       STARCH, CORN
# 156                                 D&amp;C RED NO. 28
# 157                                FD&amp;C BLUE NO. 1
# 158                                FD&amp;C RED NO. 40
# 159                                   FERRIC OXIDE RED
# 160                               GELATIN, UNSPECIFIED
# 161                              GLYCERYL MONOSTEARATE
# 162             HYDROXYPROPYL CELLULOSE (1600000 WAMW)
# 163                          HYPROMELLOSE, UNSPECIFIED
# 164                                 MAGNESIUM STEARATE
# 165  METHACRYLIC ACID - METHYL METHACRYLATE COPOLYM...
# 166                                     POLYSORBATE 80
# 167                                            SUCROSE
# 168                                               TALC
# 169                                   TITANIUM DIOXIDE
# 170                                   TRIETHYL CITRATE
# 171                   ESOMEPRAZOLE MAGNESIUM DIHYDRATE
# 172                             ESOMEPRAZOLE MAGNESIUM
# 173                              GLYCERYL MONOSTEARATE
# 174             HYDROXYPROPYL CELLULOSE (1600000 WAMW)
# 175                                      HYPROMELLOSES
# 176                                 MAGNESIUM STEARATE
# 177                                   METHACRYLIC ACID
# 178                                  POTASSIUM SORBATE
# 179                                               TALC
# 180                                   TRIETHYL CITRATE
# 181                                              WATER
# 182                                 ANHYDROUS DEXTROSE
# 183                              POVIDONE, UNSPECIFIED
# 184                              ANHYDROUS CITRIC ACID
# 185                                FERRIC OXIDE YELLOW
# 186                                            ALCOHOL
# 187                             ESOMEPRAZOLE MAGNESIUM
# 188                              GLYCERYL MONOSTEARATE
# 189                            HYDROXYPROPYL CELLULOSE
# 190                                      HYPROMELLOSES
# 191                                 MAGNESIUM STEARATE
# 192                                   METHACRYLIC ACID
# 193                                               TALC
# 194                                   TRIETHYL CITRATE
# 195                                     POLYSORBATE 80
# 196                                            GELATIN
# 197                                FD&amp;C BLUE NO. 1
# 198                                FD&amp;C RED NO. 40
# 199                                 D&amp;C RED NO. 28
# 200                                   TITANIUM DIOXIDE
# 201                                            ALCOHOL
# 202                                  ISOPROPYL ALCOHOL
# 203                                      BUTYL ALCOHOL
# 204                                POLYETHYLENE GLYCOL
# 205                                   SODIUM HYDROXIDE
# 206                                           POVIDONE
# 207                              D&amp;C YELLOW NO. 10
# 208                             ESOMEPRAZOLE MAGNESIUM
# 209                              GLYCERYL MONOSTEARATE
# 210                            HYDROXYPROPYL CELLULOSE
# 211                                      HYPROMELLOSES
# 212                                 MAGNESIUM STEARATE
# 213                                   METHACRYLIC ACID
# 214                                               TALC
# 215                                   TRIETHYL CITRATE
# 216                                     POLYSORBATE 80
# 217                                            GELATIN
# 218                                FD&amp;C BLUE NO. 1
# 219                                FD&amp;C RED NO. 40
# 220                                 D&amp;C RED NO. 28
# 221                                   TITANIUM DIOXIDE
# 222                                            ALCOHOL
# 223                                  ISOPROPYL ALCOHOL
# 224                                      BUTYL ALCOHOL
# 225                                POLYETHYLENE GLYCOL
# 226                                   SODIUM HYDROXIDE
# 227                                           POVIDONE
# 228                              D&amp;C YELLOW NO. 10
# 229                             ESOMEPRAZOLE MAGNESIUM
# 230                              GLYCERYL MONOSTEARATE
# 231                            HYDROXYPROPYL CELLULOSE
# 232                                      HYPROMELLOSES
# 233                                 MAGNESIUM STEARATE
# 234                                   METHACRYLIC ACID
# 235                                               TALC
# 236                                   TRIETHYL CITRATE
# 237                                     POLYSORBATE 80
# 238                                            GELATIN
# 239                                FD&amp;C BLUE NO. 1
# 240                                FD&amp;C RED NO. 40
# 241                                 D&amp;C RED NO. 28
# 242                                   TITANIUM DIOXIDE
# 243                                            ALCOHOL
# 244                                  ISOPROPYL ALCOHOL
# 245                                      BUTYL ALCOHOL
# 246                                POLYETHYLENE GLYCOL
# 247                                   SODIUM HYDROXIDE
# 248                                           POVIDONE
# 249                              D&amp;C YELLOW NO. 10
# 250                             ESOMEPRAZOLE MAGNESIUM
# 251                              GLYCERYL MONOSTEARATE
# 252                            HYDROXYPROPYL CELLULOSE
# 253                                      HYPROMELLOSES
# 254                                 MAGNESIUM STEARATE
# 255                                   METHACRYLIC ACID
# 256                                               TALC
# 257                                   TRIETHYL CITRATE
# 258                                     POLYSORBATE 80
# 259                                            GELATIN
# 260                                FD&amp;C BLUE NO. 1
# 261                                FD&amp;C RED NO. 40
# 262                                 D&amp;C RED NO. 28
# 263                                   TITANIUM DIOXIDE
# 264                                            ALCOHOL
# 265                                  ISOPROPYL ALCOHOL
# 266                                      BUTYL ALCOHOL
# 267                                POLYETHYLENE GLYCOL
# 268                                   SODIUM HYDROXIDE
# 269                                           POVIDONE
# 270                              D&amp;C YELLOW NO. 10
# 271                             ESOMEPRAZOLE MAGNESIUM
# 272                              GLYCERYL MONOSTEARATE
# 273             HYDROXYPROPYL CELLULOSE (1600000 WAMW)
# 274                          HYPROMELLOSE, UNSPECIFIED
# 275                                 MAGNESIUM STEARATE
# 276                                   METHACRYLIC ACID
# 277                                               TALC
# 278                                   TRIETHYL CITRATE
# 279                                     POLYSORBATE 80
# 280                               GELATIN, UNSPECIFIED
# 281                                FD&amp;C BLUE NO. 1
# 282                                FD&amp;C RED NO. 40
# 283                                 D&amp;C RED NO. 28
# 284                                   TITANIUM DIOXIDE
# 285                                            ALCOHOL
# 286                                  ISOPROPYL ALCOHOL
# 287                                      BUTYL ALCOHOL
# 288                   POLYETHYLENE GLYCOL, UNSPECIFIED
# 289                                   SODIUM HYDROXIDE
# 290                              POVIDONE, UNSPECIFIED
# 291                              D&amp;C YELLOW NO. 10
# 292                             ESOMEPRAZOLE MAGNESIUM
# 293                              GLYCERYL MONOSTEARATE
# 294                            HYDROXYPROPYL CELLULOSE
# 295                                       HYPROMELLOSE
# 296                                 MAGNESIUM STEARATE
# 297                                   METHACRYLIC ACID
# 298                                               TALC
# 299                                     POLYSORBATE 80
# 300                                   TRIETHYL CITRATE
# 301                                            GELATIN
# 302                                FD&amp;C BLUE NO. 1
# 303                                FD&amp;C RED NO. 40
# 304                                 D&amp;C RED NO. 28
# 305                                   TITANIUM DIOXIDE
# 306                                            ALCOHOL
# 307                                  ISOPROPYL ALCOHOL
# 308                                      BUTYL ALCOHOL
# 309                                POLYETHYLENE GLYCOL
# 310                                   SODIUM HYDROXIDE
# 311                                           POVIDONE
# 312                              D&amp;C YELLOW NO. 10

# %%
def writeHandlesToFile():
    while True:
        with open("dataFile.txt","w") as f:
            try:
                lst = tweepy.Cursor(tweepy.api.followers,screen_name='someHandle',).items(100000)
                print "cursor executed"
                for item in lst:
                    f.write(item.screen_name+"\n")
                break
            except tweepy.error.TweepError as e:
                print "In the except method"
                print e
                time.sleep(3600)
